# %%
import numpy as np
from scipy import stats as st
import statistics as stat
import pandas as pd

# %% [markdown]
#      1. Scenario: A company wants to analyze the sales performance of its products in different
#     regions. They have collected the following data:
#     Region A: [10, 15, 12, 8, 14]
#     Region B: [18, 20, 16, 22, 25]
#     Calculate the mean sales for each region.

# %%
Region_A = [10, 15, 12, 8, 14]
Region_B = [18, 20, 16, 22, 25]

mean_for_region_A = np.mean(Region_A)
mean_for_region_B = np.mean(Region_B)

print(f"Mean of the Region A is {mean_for_region_A}")
print(f"Mean of the Region B is {mean_for_region_B}")
# Out:
# Mean of the Region A is 11.8
# Mean of the Region B is 20.2

# %% [markdown]
#     2. Scenario: A survey is conducted to measure customer satisfaction on a scale of 1 to 5. The
#     data collected is as follows:
#     [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]
#     Calculate the mode of the survey responses.

# %%
satisfaction = [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]

Mode_of_sat = list(st.mode(satisfaction))
print(f"Mode of the survey responses is {Mode_of_sat[0][0]} and it's frequency is {Mode_of_sat[1][0]}")

# %% [markdown]
#     3. Scenario: A company wants to compare the salaries of two departments. The salary data for
#     Department A and Department B are as follows:
#     Department A: [5000, 6000, 5500, 7000]
#     Department B: [4500, 5500, 5800, 6000, 5200]
#     Calculate the median salary for each department.

# %%
Department_A =  [5000, 6000, 5500, 7000]
Department_B = [4500, 5500, 5800, 6000, 5200]


Median_Department_A = stat.median(Department_A)
Median_Department_B = stat.median(Department_B)


print(f"Median Salary of Department A is {Median_Department_A} and Department B is {Median_Department_B}")

# %% [markdown]
#     4. Scenario: A data analyst wants to determine the variability in the daily stock prices of a
#     company. The data collected is as follows:
#     [25.5, 24.8, 26.1, 25.3, 24.9]
#     Calculate the range of the stock prices.

# %%
stock_price = [25.5, 24.8, 26.1, 25.3, 24.9]
min_value = min(stock_price)
max_value = max(stock_price)
print(f"Range of stock price is {min_value}  and  {max_value}")

# %% [markdown]
#     5. Scenario: A study is conducted to compare the performance of two different teaching
#     methods. The test scores of the students in each group are as follows:
#     Group A: [85, 90, 92, 88, 91]
#     Group B: [82, 88, 90, 86, 87]
#     Perform a t-test to determine if there is a significant difference in the mean scores between the
#     two groups.
#
#    ![t_test_formula.png](attachment:t_test_formula.png)

# %%
Group_A= [85, 90, 92, 88, 91]
Group_B= [82, 88, 90, 86, 87]

# %%
(A_square - (A_sum/nA)) + (B_square - (B_sum/nB))

# %%
mean_A = np.mean(Group_A)
mean_B = np.mean(Group_B)
nA = 5
nB = 5
A_square = np.sum(np.square(Group_A))
B_square = np.sum(np.square(Group_B))
A_sum = np.square(np.sum(Group_A))
B_sum = np.square(np.sum(Group_B))
df = (nA-1) + (nB-1)

# %%
deno = np.sqrt( ((1/nA) +(1/nB)) * ((A_square - (A_sum/nA)) + (B_square - (B_sum/nB))) *(1/df)          )
num = mean_A - mean_B
t_cal =num / deno
print(t_cal)

# %% [markdown]
# Let's consider alpha=.05 as alpha is not given. df = 8
# t_table = 2.306
#
# t_cal < t_table.
#
# so, we can conclude that there is no significant difference in teachings

# %% [markdown]
#     6. Scenario: A company wants to analyze the relationship between advertising expenditure and
#     sales. The data collected is as follows:
#     Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
#     Sales (in thousands): [25, 30, 28, 20, 26]
#     Calculate the correlation coefficient between advertising expenditure and sales.
#    ![correlation_coefficient_formula.png](attachment:correlation_coefficient_formula.png)

# %%
Expenditure = [10, 15, 12, 8, 14]
Sales = [25, 30, 28, 20, 26]

# %%
df = pd.DataFrame(zip(Expenditure,Sales),columns=["Expenditure","Sales"])

# %%
df.corr()
# Out:
#              Expenditure     Sales
# Expenditure     1.000000  0.875751
# Sales           0.875751  1.000000

# %%
7. Scenario: A survey is conducted to measure the heights of a group of people. The data
collected is as follows:
[160, 170, 165, 155, 175, 180, 170]
Calculate the standard deviation of the heights.

# %%
mean = np.mean(height)
standard_deviation =np.sqrt(np.sum( [(ele - mean)**2 for ele in height])/7)
standard_deviation
# Out:
# 7.953949089757174

# %% [markdown]
#     8. Scenario: A company wants to analyze the relationship between employee tenure and job
#     satisfaction. The data collected is as follows:
#     Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
#     Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]
#     Perform a linear regression analysis to predict job satisfaction based on employee tenure.

# %%
from sklearn.linear_model import LinearRegression
Employee_Tenure= np.array([2, 3, 5, 4, 6, 2, 4])
Job_Satisfaction =np.array([7, 8, 6, 9, 5, 7, 6])

# %%
Employee_Tenure = Employee_Tenure.reshape(-1,1)
Employee_Tenure , Job_Satisfaction
# Out:
# (array([[2],
#         [3],
#         [5],
#         [4],
#         [6],
#         [2],
#         [4]]),
#  array([7, 8, 6, 9, 5, 7, 6]))

# %%
model = LinearRegression()
model.fit(Employee_Tenure,Job_Satisfaction)
# Out:
# LinearRegression()

# %%
model.predict([[6]])
# Out:
# array([5.78723404])

# %% [markdown]
#     9. Scenario: A study is conducted to compare the effectiveness of two different medications.
#     The recovery times of the patients in each group are as follows:
#     Medication A: [10, 12, 14, 11, 13]
#     Medication B: [15, 17, 16, 14, 18]
#     Perform an analysis of variance (ANOVA) to determine if there is a significant difference in the
#     mean recovery times between the two medications.

# %% [markdown]
# Formula:-
#
#     ANOVA coefficient, F =  Mean sum of squares between the groups (MSB)/ Mean squares of errors (MSE).
#
#     Therefore F = MSB/MSE
#
#     Mean squares between groups, MSB = SSB / (k – 1)
#
#     Mean squares of errors, MSE = SSE / (N – k)
#
#     N – k = df2 here, N is the total number of observations throughout k groups.
#
#    ![Anova.png](attachment:Anova.png)

# %%
SSE = [(mean_A -ele) **2 for ele in medication_A]

# %%
medication_A = [10, 12, 14, 11, 13]
medication_B = [15, 17, 16, 14, 18]

# %%
mean_A = np.mean(medication_A)
mean_B = np.mean(medication_B)
grand_mean = (mean_A + mean_B)/2

# %%
SSB = np.sum([(mean_A - grand_mean)**2 for ele in medication_A]) +\
        np.sum([(mean_B - grand_mean)**2 for ele in medication_B])
      
df_between_group = 2-1 
MSB = SSB/df_between_group

# %%
SSE = np.sum([(ele - mean_A)**2 for ele in medication_A]) + np.sum([(ele - mean_B)**2 for ele in medication_B])
MSE = SSE / 8
MSE
# Out:
# 2.5

# %%
f = MSB/MSE
print(f)
# Out:
# 16.0

# %%
from scipy.stats import f_oneway

# %%
f_oneway(medication_A,medication_B)
# Out:
# F_onewayResult(statistic=16.0, pvalue=0.003949772803445326)

# %% [markdown]
# Here p value is less than alpha(.05), so we can tell that there is significant difference in the
# mean recovery times between the two medications.

# %% [markdown]
#     10. Scenario: A company wants to analyze customer feedback ratings on a scale of 1 to 10. The
#     data collected is
#     as follows:
#     [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]
#     Calculate the 75th percentile of the feedback ratings.

# %%
rating = [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]
percentile_75 = np.percentile(rating,75)
print(percentile_75)
# Out:
# 8.75

# %% [markdown]
#     11. Scenario: A quality control department wants to test the weight consistency of a product.
#     The weights of a sample of products are as follows:
#     [10.2, 9.8, 10.0, 10.5, 10.3, 10.1]
#     Perform a hypothesis test to determine if the mean weight differs significantly from 10 grams.

# %%
import scipy.stats as stats
weight = [10.2, 9.8, 10.0, 10.5, 10.3, 10.1]

# %%
mean_weight = np.mean(weight)
mean_weight
# Out:
# 10.15

# %%
H_0 - significant_weight_difference != 10g
H_A - significant_weight_difference == 10g

# %%
t_statistic, p_value = stats.ttest_1samp(a=weight, popmean=10.25)
print(t_statistic , p_value)
# Out:
# -1.0084389681792185 0.35952535593324597

# %%
t_statistic, p_value = stats.ttest_1samp(a=weight, popmean=10.05)
print(t_statistic , p_value)
# Out:
# 1.0084389681792185 0.35952535593324597

# %% [markdown]
# p_value is more than 0.05, so we will accept the H_0 and we can conclude that there is no
# significane difference of 10g in the weight

# %% [markdown]
#     12. Scenario: A company wants to analyze the click-through rates of two different website
#     designs. The number of clicks for each design is as follows:
#     Design A: [100, 120, 110, 90, 95]
#     Design B: [80, 85, 90, 95, 100]
#     Perform a chi-square test to determine if there is a significant difference in the click-through
#     rates between the two designs.

# %%
H_0 - there is no significant difference in the click-through rates between the two designs.
H_A - there is a significant difference in the click-through rates between the two designs.

# %%
from scipy.stats import chi2_contingency
 
# defining the table
data = [[100, 120, 110, 90, 95], [80, 85, 90, 95, 100]]
stat, p, dof, expected = chi2_contingency(data)
 
# interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# p value is 0.19103526314060293
# Independent (H0 holds true)

# %% [markdown]
#     13. Scenario: A survey is conducted to measure customer satisfaction with a product on a scale
#     of 1 to 10. The data collected is as follows:
#     [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]
#     Calculate the 95% confidence interval for the population mean satisfaction score.

# %%
data = [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]

# %%
 t(for df=9 and one tailed ) = 1.833

# %%
#Margin_of_error = t(for df=9 and one tailed ) * (s.d /sqrt(n))
Margin_of_Error = 1.833*(np.std(data) / np.sqrt(10))

# %%
CI_lower = np.mean(data) - Margin_of_Error
CI_upper =  np.mean(data) + Margin_of_Error

# %%
print(f"confidence interval lower value is {CI_lower} and upper value is {CI_upper}")
# Out:
# confidence interval lower value is 7.241649272044149 and upper value is 8.558350727955853

# %% [markdown]
#     14. Scenario: A company wants to analyze the effect of temperature on product performance.
#     The data collected is as follows:
#     Temperature (in degrees Celsius): [20, 22, 23, 19, 21]
#     Performance (on a scale of 1 to 10): [8, 7, 9, 6, 8]
#     Perform a simple linear regression to predict performance based on temperature.

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
temp = np.array([20, 22, 23, 19, 21]).reshape(-1,1)
perf = [8, 7, 9, 6, 8]
model.fit(temp,perf)
# Out:
# LinearRegression()

# %%
model.predict(temp)
# Out:
# array([7.1, 8.1, 8.6, 6.6, 7.6])

# %% [markdown]
#     15. Scenario: A study is conducted to compare the preferences of two groups of participants.
#     The preferences are measured on a Likert scale from 1 to 5. The data collected is as follows:
#     Group A: [4, 3, 5, 2, 4]
#     Group B: [3, 2, 4, 3, 3]
#     Perform a Mann-Whitney U test to determine if there is a significant difference in the median
#     preferences between the two groups.

# %%
from scipy.stats import mannwhitneyu
Group_A= [4, 3, 5, 2, 4]
Group_B= [3, 2, 4, 3, 3]

# %%
stat, p_value = mannwhitneyu(Group_A, Group_B)
print('Statistics=%.2f, p=%.2f' % (stat, p_value))
# Out:
# Statistics=17.00, p=0.38

# %% [markdown]
# p value is more than .05, so we can tell there is no significant difference in the median
# preferences between the two groups.

# %% [markdown]
#     16. Scenario: A company wants to analyze the distribution of customer ages. The data collected
#     is as follows:
#     [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#     Calculate the interquartile range (IQR) of the ages.

# %%
data = [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]

# %%
q1 = np.percentile(data,25)
q3 = np.percentile(data,75)
IQR = q3-q1
print(f"Interquantile range(IQR) is {IQR}")
# Out:
# Interquantile range(IQR) is 22.5

# %% [markdown]
#     17. Scenario: A study is conducted to compare the performance of three different machine
#     learning algorithms. The accuracy scores for each algorithm are as follows:
#     Algorithm A: [0.85, 0.80, 0.82, 0.87, 0.83]
#     Algorithm B: [0.78, 0.82, 0.84, 0.80, 0.79]
#     Algorithm C: [0.90, 0.88, 0.89, 0.86, 0.87]
#     Perform a Kruskal-Wallis test to determine if there is a significant difference in the median
#     accuracy scores between the algorithms.

# %%
from scipy.stats import kruskal

# %%
Algorithm_A= [0.85, 0.80, 0.82, 0.87, 0.83]
Algorithm_B= [0.78, 0.82, 0.84, 0.80, 0.79]
Algorithm_C= [0.90, 0.88, 0.89, 0.86, 0.87]


stat, p = kruskal(Algorithm_A, Algorithm_B, Algorithm_C)
print(f"p-value is {p}")
# Out:
# p-value is 0.007840333026249539

# %%
print("Pvalue is less than 0.05, so we can conlcude that there is not significant difference in the median\
accuracy scores between the algorithms.")
# Out:
# Pvalue is less than 0.05, so we can conlcude that there is not significant difference in the medianaccuracy scores between the algorithms.

# %% [markdown]
#     18. Scenario: A company wants to analyze the effect of price on sales. The data collected is as
#     follows:
#     Price (in dollars): [10, 15, 12, 8, 14]
#     Sales: [100, 80, 90, 110, 95]
#     Perform a simple linear regression to predict
#     sales based on price.

# %%
price = np.array([10, 15, 12, 8, 14]).reshape(-1,1)
sales = [100, 80, 90, 110, 95]

# %%
model = LinearRegression()

# %%
model.fit(price,sales)
# Out:
# LinearRegression()

# %%
model.predict([[9]])
# Out:
# array([104.81707317])

# %% [markdown]
#     19. Scenario: A survey is conducted to measure the satisfaction levels of customers with a new
#     product. The data collected is as follows:
#     [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]
#     Calculate the standard error of the mean satisfaction score.

# %%
data= [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]

standard_error = np.std(data) / np.sqrt(len(data))
print(f"Standard Error of the given data is {standard_error}")
# Out:
# Standard Error of the given data is 0.28982753492378877

# %% [markdown]
#     20. Scenario: A company wants to analyze the relationship between advertising expenditure
#     and sales. The data collected is as follows:
#     Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
#     Sales (in thousands): [25, 30, 28, 20, 26]
#     Perform a multiple regression analysis to predict sales based on advertising expenditure.

# %%
Advertising = np.array([10, 15, 12, 8, 14]).reshape(-1,1)
sales = [25, 30, 28, 20, 26]

# %%
model =LinearRegression()
model.fit(Advertising,sales)
# Out:
# LinearRegression()

# %%
model.predict([[9]])
# Out:
# array([22.57317073])
